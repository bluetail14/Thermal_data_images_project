# %% [markdown]
# ### Models
#
# ## - CNN
# ## - CNN-LTSM
# ## - VGG16
# ## - ResNet50
# ## - Visual Transformers (ViT)
# ## - AlexNet

# %%
import numpy as np
import pandas as pd
import os
import pickle
import cv2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from keras.models import Sequential, load_model
from keras.layers.core import Dense, Activation

from keras.layers import Dropout, Flatten, Input
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Reshape
from keras.models import Model
from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import ResNet50
from transformers import ViTFeatureExtractor, TFViTModel

from tensorflow.keras.optimizers import Adam, SGD 
from keras.optimizers import gradient_descent_v2 

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, confusion_matrix

from tensorflow.keras.utils import Sequence

from sklearn.metrics import classification_report, confusion_matrix,ConfusionMatrixDisplay

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos'

# %%
path_train = "../Camera_videos/Images3sec_traindata_v2"

# %%
path_train
# Out:
# '../Camera_videos/Images3sec_traindata_v2'

# %%
path_test = "../Camera_videos/Images_3sec_testdata_v2"

# %%
path_test
# Out:
# '../Camera_videos/Images_3sec_testdata_v2'

# %% [markdown]
# ### Defining the class to load images

# %%
class MasterImage0(object):

    def __init__(self,PATH = '', IMAGE_SIZE = 224):
        self.PATH = PATH
        self.IMAGE_SIZE = IMAGE_SIZE

        self.image_data = []
        self.x_data = []
        self.y_data = []
        self.CATEGORIES = []

        # This will get List of categories
        self.list_categories = []

    def get_categories(self):
        for path in os.listdir(self.PATH):
            if '.DS_Store' in path:
                pass
            else:
                self.list_categories.append(path)
        print("Found Categories ", self.list_categories,'\n')    
        return self.list_categories

    def process_image(self):
    
        """
        Return Numpy array of image
        :return: X_Data, Y_Data
        """
        self.CATEGORIES = self.get_categories()
        for categories in self.CATEGORIES:                                                  # Iterate over categories

            train_folder_path = os.path.join(self.PATH, categories)                         # Folder Path
            class_index = self.CATEGORIES.index(categories)                                 # this will get index for classification

            for img in os.listdir(train_folder_path):                                       # This will iterate in the Folder
                new_path = os.path.join(train_folder_path, img)                           # image Path
                
                try:        # if any image is corrupted
                    image_data_temp = cv2.imread(new_path)                 # Read Image as numbers
                    image_temp_resize = cv2.resize(image_data_temp,(self.IMAGE_SIZE,self.IMAGE_SIZE))
                    self.image_data.append([image_temp_resize,class_index])
                    random.shuffle(self.image_data)
                
                except:
                    pass

        data = np.asanyarray(self.image_data, dtype=object)
    
        # Iterate over the Data
        for x in data:
            self.x_data.append(x[0])        # Get the X_Data
            self.y_data.append(x[1])        # get the label
        print(self.x_data)
        x_data = np.asarray(self.x_data) / (255.0)      # Rescale Data
        y_data = np.asarray(self.y_data)
        
        # Reshape X_data
        x_data = x_data.reshape(-1, self.IMAGE_SIZE, self.IMAGE_SIZE, 3)     
        print("Compiled X_data", len(self.x_data))
        return x_data, y_data


    def pickle_image(self):

        """
        :return: None Creates a Pickle Object of DataSet
        """
        # Call the Function and Get the Data
        x_data,y_data = self.process_image()

        # Write the Entire Data into a Pickle File
        pickle_out = open('C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images3sec_traindata_v2\\x_data','wb')
        pickle.dump(x_data, pickle_out)
        pickle_out.close()

        # Write the Y Label Data
        pickle_out = open('C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images3sec_traindata_v2\\y_data', 'wb')
        pickle.dump(y_data, pickle_out)
        pickle_out.close()

        print("Pickled Image Successfully ")
        return x_data, y_data
        print(self.x_data)

    def load_dataset(self):

        try:
            # Read the Data from Pickle Object
            X_Temp = open('C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images3sec_traindata_v2\\x_data','rb')
            X_Data = pickle.load(X_Temp)

            Y_Temp = open('C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images3sec_traindata_v2\\y_data','rb')
            Y_Data = pickle.load(Y_Temp)

            print('Reading Dataset from Pickle Object')

            return X_Data,Y_Data

        except:
            print('Could not Found Pickle File ')
            print('Loading File and Dataset  ..........')

            x_data,y_data = self.pickle_image()
            print("X_data", self.x_data)
            return x_data,y_data

# %% [markdown]
# ### Train data

# %%
# Using the 224 x 224 size
a = MasterImage0(PATH = path_train,IMAGE_SIZE = 224)
a

# %%
(all_images, all_labels) = a.load_dataset()
# Out:
# Reading Dataset from Pickle Object

# %%
print(all_images.shape, all_labels.shape)
# Out:
# (1209, 224, 224, 3) (1209,)

# %%
# 3 categories - Noone as 0, oneman as 1 and twomen as 2
np.unique(all_labels)
# Out:
# array([0, 1, 2])

# %% [markdown]
# ### Test data

# %%
class MasterImage1(object):

    def __init__(self,PATH = '', IMAGE_SIZE = 224):
        self.PATH = PATH
        self.IMAGE_SIZE = IMAGE_SIZE

        self.image_data = []
        self.x_data = []
        self.y_data = []
        self.CATEGORIES = []

        # This will get List of categories
        self.list_categories = []

    def get_categories(self):
        for path in os.listdir(self.PATH):
            if '.DS_Store' in path:
                pass
            else:
                self.list_categories.append(path)
        print("Found Categories ", self.list_categories,'\n')    
        return self.list_categories

    def process_image(self):
    
        """
        Return Numpy array of image
        :return: X_Data, Y_Data
        """
        self.CATEGORIES = self.get_categories()
        for categories in self.CATEGORIES:                                                  # Iterate over categories

            train_folder_path = os.path.join(self.PATH, categories)                         # Folder Path
            class_index = self.CATEGORIES.index(categories)                                 # this will get index for classification

            for img in os.listdir(train_folder_path):                                       # This will iterate in the Folder
                new_path = os.path.join(train_folder_path, img)                           # image Path
                
                try:        # if any image is corrupted
                    image_data_temp = cv2.imread(new_path)                 # Read Image as numbers
                    image_temp_resize = cv2.resize(image_data_temp,(self.IMAGE_SIZE,self.IMAGE_SIZE))
                    self.image_data.append([image_temp_resize,class_index])
                    random.shuffle(self.image_data)
                
                except:
                    pass

        data = np.asanyarray(self.image_data, dtype=object)
    
        # Iterate over the Data
        for x in data:
            self.x_data.append(x[0])        # Get the X_Data
            self.y_data.append(x[1])        # get the label
        print(self.x_data)
        x_data = np.asarray(self.x_data) / (255.0)      # Rescale Data
        y_data = np.asarray(self.y_data)
        
        # Reshape X_data
        x_data = x_data.reshape(-1, self.IMAGE_SIZE, self.IMAGE_SIZE, 3)     
        print("Compiled X_data", len(self.x_data))
        return x_data, y_data


    def pickle_image(self):

        """
        :return: None Creates a Pickle Object of DataSet
        """
        # Call the Function and Get the Data
        x_data,y_data = self.process_image()

        # Write the Entire Data into a Pickle File
        pickle_out = open('C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images_3sec_testdata_v2\\x_data1','wb')
        pickle.dump(x_data, pickle_out)
        pickle_out.close()

        # Write the Y Label Data
        pickle_out = open('C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images_3sec_testdata_v2\\y_data1', 'wb')
        pickle.dump(y_data, pickle_out)
        pickle_out.close()

        print("Pickled Image Successfully ")
        return x_data, y_data
        print(self.x_data)

    def load_dataset(self):

        try:
            # Read the Data from Pickle Object
            X_Temp = open("C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images_3sec_testdata_v2\\x_data1",'rb')
            X_Data = pickle.load(X_Temp)

            Y_Temp = open("C:\\Users\\maria\\Jupiter_Notebooks\\Dataset_Thermal_Project\\Camera_videos\\Images_3sec_testdata_v2\\y_data1",'rb')
            Y_Data = pickle.load(Y_Temp)
        
            print('Reading Dataset from Pickle Object')

            return X_Data,Y_Data

        except:
            print('Could not Found Pickle File ')
            print('Loading File and Dataset  ..........')

            x_data,y_data = self.pickle_image()
            print("X_data", self.x_data)
            return x_data,y_data

# %%
b = MasterImage1(PATH = path_test, IMAGE_SIZE = 224)

# %%
(X_test_images, y_test_labels) = b.load_dataset()
# Out:
# Reading Dataset from Pickle Object

# %%
index = np.random.choice(X_test_images.shape[0])
image = X_test_images[index, :, :]
np.shape(image)
# Out:
# (224, 224, 3)

# %%
print(np.unique(y_test_labels))
# Out:
# [0 1]

# %%
print(X_test_images.shape, y_test_labels.shape)
# Out:
# (315, 224, 224, 3) (315,)

# %%
np.unique(y_test_labels)
# Out:
# array([0, 1])

# %% [markdown]
# ### Defining the Man images category as '1' vs  Nobody as '0' for the Train set

# %%
### Defining Man or Two Man as 1 vs Nobody as 0.
all_labels_binary = np.where(all_labels==2, 1, all_labels)

# %%
all_labels_binary = all_labels_binary.reshape(all_labels_binary.shape[0],1)

# %%
all_labels.shape
# Out:
# (1209,)

# %% [markdown]
# ### Defining Train and Validation images

# %%
np.unique(all_labels_binary, return_counts=True, axis=0)
# Out:
# (array([[0],
#         [1]]),
#  array([386, 823], dtype=int64))

# %%
# Setting 25% of the training set as the validation set
X_train_images, X_val_images, y_train_labels, y_val_labels = train_test_split(all_images, all_labels_binary, stratify= all_labels_binary,random_state=12, test_size=0.25)

# %%
# test image counts
np.unique(y_test_labels, return_counts=True, axis=0)
# Out:
# (array([0, 1]), array([151, 164], dtype=int64))

# %%
print('Train: X_train_images=%s, y_train_labels=%s' % (X_train_images.shape, y_train_labels.shape))
print('Validation: X_val_images=%s, y_val_labels=%s' % (X_val_images.shape, y_val_labels.shape))
print('Test: X_test_images=%s, y_test_labels=%s' % (X_test_images.shape, y_test_labels.shape))
# Out:
# Train: X_train_images=(906, 224, 224, 3), y_train_labels=(906, 1)
# Validation: X_val_images=(303, 224, 224, 3), y_val_labels=(303, 1)
# Test: X_test_images=(315, 224, 224, 3), y_test_labels=(315,)

# %%
# Verify images from the train set
class_names = ['noone', 'man']

plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train_images[i])
    plt.xlabel(class_names[y_train_labels[i][0]])
plt.show()

# %%
# Verify images from the validation set
class_names = ['noone', 'man']
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_val_images[i])
    plt.xlabel(class_names[y_val_labels[i][0]])
plt.show()

# %%
# Verify images from the test set

class_names = ['noone', 'man']
plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test_images[i])
    plt.xlabel(class_names[y_test_labels[i]])
plt.show()

# %%
y_test_labels.shape
# Out:
# (315,)

# %% [markdown]
# ### Data Augmentation
#
# See the Keras tutorial on image augmentation at https://www.tensorflow.org/tutorials/images/data_augmentation and the preprocessing layers at https://www.tensorflow.org/guide/keras/preprocessing_layers .

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal"), #  Applies horizontal flipping (i.e. the man sitting on the left will swap to the right and vice versa) 
                                                # to a random 50% of the images that go through it
  layers.RandomCrop(120,120),  # Crops out a random part of an image to the size 120 x 120
  layers.RandomZoom(0.2),  # Zooms in or out of the image by a random factor in the range [-20%, +20%]
  layers.RandomRotation(0.3), # Rotates the input images by a random value in the range [–30%, +30%]
  layers.RandomContrast(factor =0.9), # Adjusts contrast during training between [10%, 90%].
])

# %%
#class_names = ['noone', 'man']
#plt.figure(figsize=(10,10))
#for i in range(25):
#    plt.subplot(5,5,i+1)
#    plt.xticks([])
#    plt.yticks([])    
#    augmented_images = data_augmentation(X_train_images)
#    plt.grid(False)
#    plt.imshow(augmented_images[i])
#    plt.xlabel(class_names[y_train_labels[i][0]])
#plt.show()

# %% [markdown]
# ## CNN Model

# %%
input_shape = X_train_images.shape[1:]
input_shape
# Out:
# (224, 224, 3)

# %%
# Define the model  - no regularisation - basic
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

x =  keras.layers.Conv2D(32, (5,5), padding = 'same', activation = 'relu')(x)
x =  keras.layers.Conv2D(64, (3,3), padding = 'same', activation = 'relu')(x)
x =  keras.layers.MaxPooling2D(2,2)(x)
x =  keras.layers.Flatten()(x)
x =  keras.layers.Dense(64, activation = 'relu')(x)

outputs = keras.layers.Dense(1,activation='sigmoid')(x)  # for binary classification
cnn_model = Model(inputs,outputs)

cnn_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 120, 120, 32)      2432
#
#  conv2d_6 (Conv2D)           (None, 120, 120, 64)      18496
#
#  max_pooling2d_3 (MaxPooling  (None, 60, 60, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 230400)            0
#
#  dense_3 (Dense)             (None, 64)                14745664
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 14,766,657
# Trainable params: 14,766,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
cnn_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
# Fit the model
cnn_trained_model = cnn_model.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels),batch_size=4, verbose=2, epochs=80)
# Out:
# Epoch 1/80
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# Epoch 80/80
# 227/227 - 6s - loss: 0.0837 - accuracy: 0.9680 - val_loss: 0.0225 - val_accuracy: 0.9967 - 6s/epoch - 28ms/step

# %%
def plot_graphs(cnn_trained_model, string):
    plt.plot(cnn_trained_model.history[string], label="train "+string)
    plt.plot(cnn_trained_model.history['val_'+string], label="validation "+string)
    plt.xlabel("Epochs")
    plt.ylabel(string)
#    plt.legend([string, 'val_'+string])
# Place a legend to the right of this smaller subplot.
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    
    
  #Plot the accuracy and loss
plot_graphs(cnn_trained_model, "accuracy")
plot_graphs(cnn_trained_model, "loss")

# %%
cnn_model.save("Saved_models/cnn_model.h5")

# %%
scores = cnn_model.evaluate(X_test_images, y_test_labels, verbose=0)
print("CNN Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# CNN Accuracy on Test Set: 90.94%

# %%
_, train_acc = cnn_model.evaluate(X_train_images, y_train_labels, verbose=0)
_, val_acc = cnn_model.evaluate(X_val_images, y_val_labels, verbose=0)
_, test_acc = cnn_model.evaluate(X_test_images, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 0.983, Validation accuracy: 0.997, Test accuracy: 0.909

# %%
y_pred_labels = cnn_model.predict(X_test_images)
y_pred_labels = y_pred_labels.flatten().round()
print(classification_report(y_test_labels, y_pred_labels, digits=3))
# Out:
# 10/10 [==============================] - 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0      0.855     0.974     0.910       151
#            1      0.972     0.848     0.906       164
#
#     accuracy                          0.908       315
#    macro avg      0.913     0.911     0.908       315
# weighted avg      0.916     0.908     0.908       315

# %%
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print('CNN model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_pred_labels)
print('CNN model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_pred_labels)
print('CNN model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_pred_labels)
print('CNN model F1-score: %.3f' % f1)
# Out:
# CNN model Accuracy:  0.908
# CNN model Precision: 0.972
# CNN model Recall: 0.848
# CNN model F1-score: 0.906

# %%
cmatrix = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()

# %%
# Define the CNN model  - with regularisation
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

x =  keras.layers.Conv2D(32, (5,5), padding = 'same', activation = 'relu')(x)
x =  keras.layers.Conv2D(64, (3,3), padding = 'same', activation = 'relu')(x)
x =  keras.layers.MaxPooling2D(2,2)(x)

x =  keras.layers.Conv2D(128, (3,3), padding = 'same', activation = 'relu')(x)
x =  keras.layers.MaxPooling2D(2,2)(x)
       
x =  keras.layers.Flatten()(x)
x =  keras.layers.Dense(64, activation = 'relu')(x)
x =  keras.layers.Dropout(0.2)(x)
x =  keras.layers.Dense(128, activation = 'relu')(x)
x =  keras.layers.Dropout(0.2)(x)

outputs = keras.layers.Dense(1,activation='sigmoid')(x)  # for binary classification
cnn_model_reg = Model(inputs,outputs)

cnn_model_reg.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  conv2d (Conv2D)             (None, 120, 120, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 120, 120, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 60, 60, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dense (Dense)               (None, 64)                7372864
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 7,476,097
# Trainable params: 7,476,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
cnn_model_reg.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
# Fit the model
cnn_reg_trained_model = cnn_model_reg.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels),verbose=2, epochs=80)
# Out:
# Epoch 1/80
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [97], in <cell line: 2>()
#       1 # Fit the model
# ----> 2 cnn_reg_trained_model = cnn_model_reg.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels),verbose=2, epochs=80)
#
# File ~\anaconda3\envs\tfenv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\envs\tfenv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'gradient_tape/model/conv2d_2/BiasAdd/BiasAddGrad' defined at (most recent call last):
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\maria\AppData\Local\Temp\ipykernel_13416\1948019735.py", line 2, in <cell line: 2>
#       cnn_reg_trained_model = cnn_model_reg.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels),verbose=2, epochs=80)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\engine\training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\engine\training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\engine\training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\engine\training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\engine\training.py", line 893, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 537, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 590, in _compute_gradients
#       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     File "C:\Users\maria\anaconda3\envs\tfenv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 471, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/model/conv2d_2/BiasAdd/BiasAddGrad'
# OOM when allocating tensor with shape[4096,3600] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/model/conv2d_2/BiasAdd/BiasAddGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_70277]

# %%
def plot_graphs(cnn_reg_trained_model, string):
    plt.plot(cnn_reg_trained_model.history[string], label="train "+string)
    plt.plot(cnn_reg_trained_model.history['val_'+string], label="validation "+string)
    plt.xlabel("Epochs")
    plt.ylabel(string)
#    plt.legend([string, 'val_'+string])
# Place a legend to the right of this smaller subplot.
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    
    
  #Plot the accuracy and loss
plot_graphs(cnn_reg_trained_model, "accuracy")
plot_graphs(cnn_reg_trained_model, "loss")

# %%
scores = cnn_model_reg.evaluate(X_test_images, y_test_labels, verbose=0)
print("CNN Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# CNN Accuracy on Test Set: 95.94%

# %%
cnn_model_reg.save("Saved_models/cnn_model_with_reg.h5")

# %%
_, train_acc = cnn_model_reg.evaluate(X_train_images, y_train_labels, verbose=0)
_, val_acc = cnn_model_reg.evaluate(X_val_images, y_val_labels, verbose=0)
_, test_acc = cnn_model_reg.evaluate(X_test_images, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 0.996, Validation accuracy: 1.000, Test accuracy: 0.959

# %% [markdown]
# ### Get accuracy, precision, recall and f measure and  confusion matrix

# %%
y_pred_labels = cnn_model_reg.predict(X_test_images)
y_pred_labels = y_pred_labels.flatten().round()
print(classification_report(y_test_labels, y_pred_labels, digits=3))
# Out:
# 10/10 [==============================] - 0s 34ms/step
#               precision    recall  f1-score   support
#
#            0      0.921     1.000     0.959       151
#            1      1.000     0.921     0.959       164
#
#     accuracy                          0.959       315
#    macro avg      0.960     0.960     0.959       315
# weighted avg      0.962     0.959     0.959       315

# %%
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print('CNN reg model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_pred_labels)
print('CNN reg model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_pred_labels)
print('CNN reg model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_pred_labels)
print('CNN reg model F1-score: %.3f' % f1)
# Out:
# CNN reg model Accuracy:  0.959
# CNN reg model Precision: 1.000
# CNN reg model Recall: 0.921
# CNN reg model F1-score: 0.959

# %%
cmatrix = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()

# %% [markdown]
# ## CNN- LTSM model

# %%
x = data_augmentation(inputs)  # Apply random data augmentation

x =  keras.layers.Conv2D(32, (5,5), padding = 'same', activation = 'relu')(x)
x =  keras.layers.Conv2D(64, (3,3), padding = 'same', activation = 'relu')(x)
x =  keras.layers.MaxPooling2D(2,2)(x)

x =  keras.layers.Conv2D(128, (3,3), padding = 'same', activation = 'relu')(x)
x =  keras.layers.MaxPooling2D(2,2)(x)
x =  keras.layers.Reshape((32,-1))(x)
x =  keras.layers.LSTM(64, activation = 'relu', return_sequences=False)(x)

x =  keras.layers.Dropout(0.2)(x)

outputs = keras.layers.Dense(1,activation='sigmoid')(x)  # for binary classification
cnn_ltsm_model = Model(inputs,outputs)

cnn_ltsm_model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 120, 120, 32)      2432
#
#  conv2d_6 (Conv2D)           (None, 120, 120, 64)      18496
#
#  max_pooling2d_3 (MaxPooling  (None, 60, 60, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  reshape (Reshape)           (None, 32, 3600)          0
#
#  lstm (LSTM)                 (None, 64)                938240
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,033,089
# Trainable params: 1,033,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
cnn_ltsm_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
cnn_ltsm_trained_model = cnn_ltsm_model.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels),verbose=2, epochs=80)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# 29/29 - 13s - loss: 0.6022 - accuracy: 0.6689 - val_loss: 0.4526 - val_accuracy: 0.8185 - 13s/epoch - 461ms/step
# Epoch 2/100
# 29/29 - 11s - loss: 0.5186 - accuracy: 0.7837 - val_loss: 0.5407 - val_accuracy: 0.8647 - 11s/epoch - 370ms/step
# Epoch 3/100
# 29/29 - 11s - loss: 0.5355 - accuracy: 0.6976 - val_loss: 0.4429 - val_accuracy: 0.7459 - 11s/epoch - 370ms/step
# Epoch 4/100
# 29/29 - 11s - loss: 0.3820 - accuracy: 0.8267 - val_loss: 0.1722 - val_accuracy: 0.8746 - 11s/epoch - 365ms/step
# Epoch 5/100
# 29/29 - 11s - loss: 0.3527 - accuracy: 0.8510 - val_loss: 0.2999 - val_accuracy: 0.8515 - 11s/epoch - 364ms/step
# Epoch 6/100
# 29/29 - 11s - loss: 0.3621 - accuracy: 0.8201 - val_loss: 0.1378 - val_accuracy: 0.9439 - 11s/epoch - 366ms/step
# Epoch 7/100
# 29/29 - 11s - loss: 0.1025 - accuracy: 0.9614 - val_loss: 0.0422 - val_accuracy: 0.9835 - 11s/epoch - 368ms/step
# Epoch 100/100
# 29/29 - 11s - loss: 0.1319 - accuracy: 0.9581 - val_loss: 0.0640 - val_accuracy: 0.9901 - 11s/epoch - 386ms/step

# %%
def plot_graphs(cnn_ltsm_trained_model, string):
 
    plt.plot(cnn_ltsm_trained_model.history[string], label="train "+string)
    plt.plot(cnn_ltsm_trained_model.history['val_'+string], label="validation "+string)
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()    
    
  #Plot the accuracy and loss
plot_graphs(cnn_ltsm_trained_model, "accuracy")
plot_graphs(cnn_ltsm_trained_model, "loss")

# %%
cnn_ltsm_model.save("Saved_models/cnn_ltsm_model.h5")

# %%
scores = cnn_ltsm_model.evaluate(X_test_images, y_test_labels, verbose=0)
print("CNN_LTSM Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# CNN_LTSM Accuracy on Test Set: 74.69%

# %%
_, train_acc = cnn_ltsm_model.evaluate(X_train_images, y_train_labels, verbose=0)
_, val_acc = cnn_ltsm_model.evaluate(X_val_images, y_val_labels, verbose=0)
_, test_acc = cnn_ltsm_model.evaluate(X_test_images, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 0.969, Validation accuracy: 0.990, Test accuracy: 0.747

# %% [markdown]
# ### Get accuracy, precision, recall and f measure and  confusion matrix

# %%
y_pred_labels = cnn_ltsm_model.predict(X_test_images)
y_pred_labels = y_pred_labels.flatten().round()
print(classification_report(y_test_labels, y_pred_labels, digits = 3))
# Out:
# 10/10 [==============================] - 0s 27ms/step
#               precision    recall  f1-score   support
#
#            0      0.961     0.483     0.643       151
#            1      0.674     0.982     0.799       164
#
#     accuracy                          0.743       315
#    macro avg      0.817     0.733     0.721       315
# weighted avg      0.811     0.743     0.724       315

# %%
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print('CNN-LTSM model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_pred_labels)
print('CNN-LTSM model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_pred_labels)
print('CNN-LTSM model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_pred_labels)
print('CNN-LTSM model F1-score: %.3f' % f1)
# Out:
# CNN-LTSM model Accuracy:  0.743
# CNN-LTSM model Precision: 0.674
# CNN-LTSM model Recall: 0.982
# CNN-LTSM model F1-score: 0.799

# %%
cmatrix = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()

# %% [markdown]
# ## VGG16 model
#
# VGG/ResNet/Inception etc are implemented following the guide on the implementation of transfer learnign from keras,  https://keras.io/guides/transfer_learning/ .

# %%
base_vgg = VGG16(include_top=False,weights='imagenet',input_shape=(120,120,3))  # Instantiate a base model with pre-trained weights.

base_vgg.trainable = False  # Freeze the base model

# Define VGG16 model. Adding data augmentation and new classifier layers
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

x = base_vgg(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)  # or, x = keras.layers.Global1Pooling2D()(x)
x = keras.layers.Dense(250,activation='relu')(x)
outputs = keras.layers.Dense(1,activation='sigmoid')(x)
model_VGG16 = Model(inputs,outputs)


model_VGG16.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 250)               128250
#
#  dense_1 (Dense)             (None, 1)                 251
#
# =================================================================
# Total params: 14,843,189
# Trainable params: 128,501
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Compile the model
model_VGG16.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
#Train VGG16 model
VGG16_trained_model = model_VGG16.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels), epochs=80)
# Out:
# Epoch 1/80
# 29/29 [==============================] - 8s 286ms/step - loss: 0.0913 - accuracy: 0.9669 - val_loss: 0.0255 - val_accuracy: 0.9967
# Epoch 2/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0664 - accuracy: 0.9746 - val_loss: 0.0121 - val_accuracy: 0.9967
# Epoch 3/80
# 29/29 [==============================] - 8s 281ms/step - loss: 0.0646 - accuracy: 0.9735 - val_loss: 0.0189 - val_accuracy: 0.9967
# Epoch 4/80
# 29/29 [==============================] - 8s 281ms/step - loss: 0.0549 - accuracy: 0.9834 - val_loss: 0.0114 - val_accuracy: 0.9967
# Epoch 5/80
# 29/29 [==============================] - 8s 283ms/step - loss: 0.0721 - accuracy: 0.9713 - val_loss: 0.0063 - val_accuracy: 0.9967
# Epoch 6/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0759 - accuracy: 0.9724 - val_loss: 0.0135 - val_accuracy: 0.9967
# Epoch 7/80
# 29/29 [==============================] - 8s 280ms/step - loss: 0.0741 - accuracy: 0.9735 - val_loss: 0.0152 - val_accuracy: 0.9967
# Epoch 8/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0824 - accuracy: 0.9636 - val_loss: 0.0118 - val_accuracy: 0.9967
# Epoch 9/80
# 29/29 [==============================] - 8s 283ms/step - loss: 0.0738 - accuracy: 0.9735 - val_loss: 0.0089 - val_accuracy: 0.9967
# Epoch 10/80
# 29/29 [==============================] - 8s 280ms/step - loss: 0.0885 - accuracy: 0.9636 - val_loss: 0.0203 - val_accuracy: 0.9967
# Epoch 11/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0874 - accuracy: 0.9691 - val_loss: 0.0104 - val_accuracy: 0.9967
# Epoch 12/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0652 - accuracy: 0.9790 - val_loss: 0.0117 - val_accuracy: 0.9934
# Epoch 13/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0836 - accuracy: 0.9669 - val_loss: 0.0216 - val_accuracy: 0.9967
# Epoch 14/80
# 29/29 [==============================] - 8s 280ms/step - loss: 0.0585 - accuracy: 0.9812 - val_loss: 0.0096 - val_accuracy: 0.9967
# Epoch 15/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0839 - accuracy: 0.9669 - val_loss: 0.0119 - val_accuracy: 0.9934
# Epoch 16/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0587 - accuracy: 0.9779 - val_loss: 0.0117 - val_accuracy: 0.9934
# Epoch 17/80
# 29/29 [==============================] - 8s 281ms/step - loss: 0.0725 - accuracy: 0.9713 - val_loss: 0.0102 - val_accuracy: 0.9967
# Epoch 18/80
# 29/29 [==============================] - 8s 281ms/step - loss: 0.0740 - accuracy: 0.9680 - val_loss: 0.0102 - val_accuracy: 0.9967
# Epoch 19/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0808 - accuracy: 0.9779 - val_loss: 0.0095 - val_accuracy: 0.9967
# Epoch 20/80
# 29/29 [==============================] - 8s 281ms/step - loss: 0.0841 - accuracy: 0.9669 - val_loss: 0.0097 - val_accuracy: 0.9967
# Epoch 21/80
# 29/29 [==============================] - 8s 283ms/step - loss: 0.0614 - accuracy: 0.9746 - val_loss: 0.0112 - val_accuracy: 0.9967
# Epoch 22/80
# 29/29 [==============================] - 8s 283ms/step - loss: 0.0561 - accuracy: 0.9757 - val_loss: 0.0109 - val_accuracy: 0.9967
# Epoch 23/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0957 - accuracy: 0.9625 - val_loss: 0.0092 - val_accuracy: 0.9967
# Epoch 24/80
# 29/29 [==============================] - 8s 283ms/step - loss: 0.0608 - accuracy: 0.9779 - val_loss: 0.0148 - val_accuracy: 0.9967
# Epoch 25/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.0813 - accuracy: 0.9658 - val_loss: 0.0076 - val_accuracy: 0.9967
# Epoch 26/80
# 29/29 [==============================] - 8s 282ms/step - loss: 0.
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    
    
  #Plot the accuracy and loss
plot_graphs(VGG16_trained_model, "accuracy")
plot_graphs(VGG16_trained_model, "loss")

# %%
model_VGG16.save("Saved_models/model_vgg16.h5")

# %%
scores = model_VGG16.evaluate(X_test_images, y_test_labels, verbose=0)
print("VGG16 Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# VGG16 Accuracy on Test Set: 96.25%

# %%
scores = model_VGG16.evaluate(X_test_images, y_test_labels, verbose=0)
print("VGG16 Accuracy on Test Set: %.2f%%" % (scores[1]*100))

# %%
_, train_acc = model_VGG16.evaluate(X_train_images, y_train_labels, verbose=0)
_, val_acc = model_VGG16.evaluate(X_val_images, y_val_labels, verbose=0)
_, test_acc = model_VGG16.evaluate(X_test_images, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 0.985, Validation accuracy: 0.997, Test accuracy: 0.962

# %% [markdown]
# ### Get accuracy, precision, recall and f measure and  confusion matrix

# %%
y_pred_labels = model_VGG16.predict(X_test_images)
y_pred_labels = y_pred_labels.flatten().round()
print(classification_report(y_test_labels, y_pred_labels, digits = 3))
# Out:
# 10/10 [==============================] - 1s 59ms/step
#               precision    recall  f1-score   support
#
#            0      1.000     0.921     0.959       151
#            1      0.932     1.000     0.965       164
#
#     accuracy                          0.962       315
#    macro avg      0.966     0.960     0.962       315
# weighted avg      0.965     0.962     0.962       315

# %%
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print('VGG16 model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_pred_labels)
print('VGG16 model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_pred_labels)
print('VGG16 model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_pred_labels)
print('VGG16 model F1-score: %.3f' % f1)
# Out:
# VGG16 model Accuracy:  0.962
# VGG16 model Precision: 0.932
# VGG16 model Recall: 1.000
# VGG16 model F1-score: 0.965

# %%
cmatrix = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()

# %% [markdown]
# ## ResNet50 model

# %%
base_resnet = ResNet50(include_top=False,weights='imagenet',input_shape=(120, 120, 3)) # Instantiate a base model

base_resnet.trainable = False  # Freeze the base model

# Define ResNet50 model. Adding new classifier layers
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)

x = base_resnet(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(250,activation='relu')(x)
outputs = keras.layers.Dense(1,activation='sigmoid')(x)
model_resnet = Model(inputs,outputs)


model_resnet.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 250)               512250
#
#  dense_6 (Dense)             (None, 1)                 251
#
# =================================================================
# Total params: 24,100,213
# Trainable params: 512,501
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# Compile the model
model_resnet.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
80
# 29/29 [==============================] - 8s 263ms/step - loss: 0.3639 - accuracy: 0.8344 - val_loss: 0.7254 - val_accuracy: 0.8185
# Epoch 73/80
# 29/29 [==============================] - 8s 266ms/step - loss: 0.4164 - accuracy: 0.8046 - val_loss: 0.4004 - val_accuracy: 0.8581
# Epoch 74/80
# 29/29 [==============================] - 8s 271ms/step - loss: 0.3801 - accuracy: 0.8179 - val_loss: 0.4083 - val_accuracy: 0.8548
# Epoch 75/80
# 29/29 [==============================] - 8s 266ms/step - loss: 0.4019 - accuracy: 0.8079 - val_loss: 0.5806 - val_accuracy: 0.8251
# Epoch 76/80
# 29/29 [==============================] - 8s 269ms/step - loss: 0.3740 - accuracy: 0.8245 - val_loss: 0.3333 - val_accuracy: 0.8614
# Epoch 77/80
# 29/29 [==============================] - 8s 267ms/step - loss: 0.3721 - accuracy: 0.8355 - val_loss: 0.4407 - val_accuracy: 0.8482
# Epoch 78/80
# 29/29 [==============================] - 8s 263ms/step - loss: 0.3530 - accuracy: 0.8466 - val_loss: 0.3523 - val_accuracy: 0.8614
# Epoch 79/80
# 29/29 [==============================] - 8s 262ms/step - loss: 0.3772 - accuracy: 0.8322 - val_loss: 0.5341 - val_accuracy: 0.8350
# Epoch 80/80
# 29/29 [==============================] - 8s 262ms/step - loss: 0.4069 - accuracy: 0.8168 - val_loss: 0.4289 - val_accuracy: 0.8548

# %%
def plot_graphs(trained_model_resnet, string):
    plt.plot(trained_model_resnet.history[string], label="train "+string)
    plt.plot(trained_model_resnet.history['val_'+string], label="validation "+string)
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    
    
  #Plot the accuracy and loss
plot_graphs(trained_model_resnet, "accuracy")
plot_graphs(trained_model_resnet, "loss")

# %%
model_resnet.save("Saved_models/model_resnet.h5")

# %%
scores = model_resnet.evaluate(X_test_images, y_test_labels, verbose=0)
print("ResNet50 Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# ResNet50 Accuracy on Test Set: 68.44%

# %%
_, train_acc = model_resnet.evaluate(X_train_images, y_train_labels, verbose=0)
_, val_acc = model_resnet.evaluate(X_val_images, y_val_labels, verbose=0)
_, test_acc = model_resnet.evaluate(X_test_images, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 0.847, Validation accuracy: 0.855, Test accuracy: 0.684

# %% [markdown]
# ### Get accuracy, precision, recall and f measure and  confusion matrix

# %%
y_pred_labels = model_resnet.predict(X_test_images)
y_pred_labels = y_pred_labels.flatten().round()
print(classification_report(y_test_labels, y_pred_labels, digits = 3))
# Out:
# 10/10 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0      1.000     0.331     0.498       151
#            1      0.619     1.000     0.765       164
#
#     accuracy                          0.679       315
#    macro avg      0.809     0.666     0.631       315
# weighted avg      0.802     0.679     0.637       315

# %%
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print('ResNet50 model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_pred_labels)
print('ResNet50 model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_pred_labels)
print('ResNet50 model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_pred_labels)
print('ResNet50 model F1-score: %.3f' % f1)
# Out:
# ResNet50 model Accuracy:  0.679
# ResNet50 model Precision: 0.619
# ResNet50 model Recall: 1.000
# ResNet50 model F1-score: 0.765

# %%
cmatrix = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()

# %% [markdown]
# ## Vision Transfomer (ViT) model

# %%
# Base model pre-trained on ImageNet-21k with the 224x224 image resolution
base_model = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.

# %%
# Google's model is pre-trained on 224x224 image resolution so cant resize by RandomCrop.
data_augmentation_vit = tf.keras.Sequential([
  layers.RandomFlip("horizontal"), 
#  layers.RandomCrop(120,120),   
  layers.RandomZoom(0.2),  
  layers.RandomRotation(0.3),
  layers.RandomContrast(factor =0.9),
])

# %%
# Freeze base model
base_model.trainable = False
# Create new model
inputs = keras.Input(shape = (3, 224, 224))
x = data_augmentation_vit(inputs)

vit = base_model.vit(inputs)[0]
vit = keras.layers.GlobalAveragePooling1D()(vit)
vit = tf.keras.layers.Dense(256, activation='relu')(vit)
vit = tf. keras.layers.Dropout(0.15)(vit)
outputs = tf.keras.layers.Dense(1, activation='sigmoid', name='outputs')(vit)

model_vit = tf.keras.Model(inputs, outputs)
print(model_vit.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 3, 224, 224)]     0
#
#  vit (TFViTMainLayer)        TFBaseModelOutputWithPoo  86389248
#                              ling(last_hidden_state=(
#                              None, 197, 768),
#                               pooler_output=(None, 76
#                              8),
#                               hidden_states=None, att
#                              entions=None)
#
#  global_average_pooling1d (G  (None, 768)              0
#  lobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 256)               196864
#
#  dropout_37 (Dropout)        (None, 256)               0
#
#  outputs (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 86,586,369
# Trainable params: 197,121
# Non-trainable params: 86,389,248
# _________________________________________________________________
# None

# %%
# Compile the model
model_vit.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
X_train_images.shape
# Out:
# (906, 224, 224, 3)

# %%
X_val_images.shape
# Out:
# (303, 224, 224, 3)

# %%
X_test_images.shape
# Out:
# (315, 224, 224, 3)

# %%
# Reshaping for the model training
X_train_images_ = np.reshape(X_train_images, (906, 3, 224, 224))
X_val_images_ = np.reshape(X_val_images, (303, 3, 224, 224))
X_test_images_ = np.reshape(X_test_images, (315, 3, 224, 224))

# %%
#Train ViT model
trained_model_vit = model_vit.fit( X_train_images_, y_train_labels, validation_data=(X_val_images_, y_val_labels), epochs=80)
# Out:
# Epoch 1/80
# 29/29 [==============================] - 19s 404ms/step - loss: 0.2692 - accuracy: 0.9051 - val_loss: 0.0784 - val_accuracy: 0.9901
# Epoch 2/80
# 29/29 [==============================] - 9s 322ms/step - loss: 0.0546 - accuracy: 0.9912 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 3/80
# 29/29 [==============================] - 9s 323ms/step - loss: 0.0192 - accuracy: 0.9989 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 4/80
# 29/29 [==============================] - 9s 323ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 5/80
# 29/29 [==============================] - 9s 327ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 6/80
# 29/29 [==============================] - 9s 327ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 7/80
# 29/29 [==============================] - 9s 323ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 8/80
# 29/29 [==============================] - 9s 325ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 9/80
# 29/29 [==============================] - 9s 321ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 10/80
# 29/29 [==============================] - 10s 335ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 11/80
# 29/29 [==============================] - 10s 335ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch
# Epoch 67/80
# 29/29 [==============================] - 9s 324ms/step - loss: 4.3718e-05 - accuracy: 1.0000 - val_loss: 3.2787e-05 - val_accuracy: 1.0000
# Epoch 68/80
# 29/29 [==============================] - 9s 324ms/step - loss: 4.5214e-05 - accuracy: 1.0000 - val_loss: 3.2037e-05 - val_accuracy: 1.0000
# Epoch 69/80
# 29/29 [==============================] - 9s 324ms/step - loss: 3.7984e-05 - accuracy: 1.0000 - val_loss: 3.0832e-05 - val_accuracy: 1.0000
# Epoch 70/80
# 29/29 [==============================] - 9s 324ms/step - loss: 3.9753e-05 - accuracy: 1.0000 - val_loss: 3.0839e-05 - val_accuracy: 1.0000
# Epoch 71/80
# 29/29 [==============================] - 9s 325ms/step - loss: 3.4089e-05 - accuracy: 1.0000 - val_loss: 2.9705e-05 - val_accuracy: 1.0000
# Epoch 72/80
# 29/29 [==============================] - 9s 325ms/step - loss: 3.9038e-05 - accuracy: 1.0000 - val_loss: 2.8401e-05 - val_accuracy: 1.0000
# Epoch 73/80
# 29/29 [==============================] - 9s 324ms/step - loss: 4.2769e-05 - accuracy: 1.0000 - val_loss: 2.8508e-05 - val_accuracy: 1.0000
# Epoch 74/80
# 29/29 [==============================] - 9s 324ms/step - loss: 3.3642e-05 - accuracy: 1.0000 - val_loss: 2.6767e-05 - val_accuracy: 1.0000
# Epoch 75/80
# 29/29 [==============================] - 9s 323ms/step - loss: 3.5813e-05 - accuracy: 1.0000 - val_loss: 2.6167e-05 - val_accuracy: 1.0000
# Epoch 76/80
# 29/29 [==============================] - 9s 324ms/step - loss: 3.1736e-05 - accuracy: 1.0000 - val_loss: 2.5585e-05 - val_accuracy: 1.0000
# Epoch 77/80
# 29/29 [==============================] - 9s 323ms/step - loss: 4.0494e-05 - accuracy: 1.0000 - val_loss: 2.5029e-05 - val_accuracy: 1.0000
# Epoch 78/80
# 29/29 [==============================] - 9s 324ms/step - loss: 2.9734e-05 - accuracy: 1.0000 - val_loss: 2.3315e-05 - val_accuracy: 1.0000
# Epoch 79/80
# 29/29 [==============================] - 9s 324ms/step - loss: 3.4062e-05 - accuracy: 1.0000 - val_loss: 2.3128e-05 - val_accuracy: 1.0000
# Epoch 80/80
# 29/29 [==============================] - 9s 323ms/step - loss: 3.4045e-05 - accuracy: 1.0000 - val_loss: 2.2711e-05 - val_accuracy: 1.0000

# %%
def plot_graphs(trained_model_vit, string):
    plt.plot(trained_model_vit.history[string], label="train "+string)
    plt.plot(trained_model_vit.history['val_'+string], label="validation "+string)
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    
    
  #Plot the accuracy and loss
plot_graphs(trained_model_vit, "accuracy")
plot_graphs(trained_model_vit, "loss")

# %%
model_vit.save("Saved_models/model_vit.h5")

# %%
scores = model_vit.evaluate(X_test_images_, y_test_labels, verbose=0)
print("ViT Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# ViT Accuracy on Test Set: 64.98%

# %%
_, train_acc = model_vit.evaluate(X_train_images_, y_train_labels, verbose=0)
_, val_acc = model_vit.evaluate(X_val_images_, y_val_labels, verbose=0)
_, test_acc = model_vit.evaluate(X_test_images_, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 1.000, Validation accuracy: 1.000, Test accuracy: 0.650

# %% [markdown]
# ### Get accuracy, precision, recall and f measure and  confusion matrix

# %%
y_predict_labels = model_vit.predict(X_test_images_)
y_predict_labels = y_predict_labels.flatten().round()
print(classification_report(y_test_labels, y_predict_labels, digits = 3))
# Out:
# 10/10 [==============================] - 4s 230ms/step
#               precision    recall  f1-score   support
#
#            0      0.583     1.000     0.737       151
#            1      1.000     0.341     0.509       164
#
#     accuracy                          0.657       315
#    macro avg      0.792     0.671     0.623       315
# weighted avg      0.800     0.657     0.618       315

# %%
accuracy = accuracy_score(y_test_labels, y_predict_labels)
print('ViT model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_predict_labels)
print('ViT model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_predict_labels)
print('ViT model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_predict_labels)
print('ViT model F1-score: %.3f' % f1)
# Out:
# ViT model Accuracy:  0.657
# ViT model Precision: 1.000
# ViT model Recall: 0.341
# ViT model F1-score: 0.509

# %%
cmatrix = confusion_matrix(y_test_labels, y_predict_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()

# %% [markdown]
# ## AlexNet

# %% [markdown]
#  It was originally designed for multi-classification. may not work as expected with binary classification?

# %%
## AlexNet model architecture

inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)

x =  keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu')(x)
x =  keras.layers.BatchNormalization()(x)
x =  keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2))(x)
x =  keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same")(x)
x =  keras.layers.BatchNormalization()(x)
x =  keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2))(x)
x =  keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same")(x)
x =  keras.layers.BatchNormalization()(x)
x =  keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same")(x)
x =  keras.layers.BatchNormalization()(x)
x =  keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same")(x)
x =  keras.layers.BatchNormalization()(x)
x =  keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2))(x)
x =  keras.layers.Flatten()(x)
x =  keras.layers.Dense(4096, activation='relu')(x)
x =  keras.layers.Dropout(0.5)(x)
x =  keras.layers.Dense(4096, activation='relu')(x)
x =  keras.layers.Dropout(0.5)(x)

outputs = keras.layers.Dense(1,activation='sigmoid')(x)
model_alexnet = Model(inputs,outputs)

print(model_alexnet.summary())
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  conv2d (Conv2D)             (None, 28, 28, 96)        34944
#
#  batch_normalization (BatchN  (None, 28, 28, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 6, 6, 384)        1536
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 384)         1327488
#
#  batch_normalization_3 (Batc  (None, 6, 6, 384)        1536
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 256)         884992
#
#  batch_normalization_4 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4096)              4198400
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 24,736,513
# Trainable params: 24,733,761
# Non-trainable params: 2,752
# _________________________________________________________________
# None

# %%
# Compile the model
model_alexnet.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
# Fit the model
trained_model_alexnet = model_alexnet.fit( X_train_images, y_train_labels, validation_data=(X_val_images, y_val_labels),verbose=2, epochs=80)
# Out:
# Epoch 1/80
# 29/29 - 8s - loss: 0.1061 - accuracy: 0.9592 - val_loss: 0.0416 - val_accuracy: 0.9901 - 8s/epoch - 260ms/step
# Epoch 2/80
# 29/29 - 7s - loss: 0.1275 - accuracy: 0.9503 - val_loss: 0.0098 - val_accuracy: 1.0000 - 7s/epoch - 251ms/step
# Epoch 3/80
# 29/29 - 7s - loss: 0.1324 - accuracy: 0.9570 - val_loss: 0.0112 - val_accuracy: 1.0000 - 7s/epoch - 254ms/step
# Epoch 4/80
# 29/29 - 7s - loss: 0.1220 - accuracy: 0.9625 - val_loss: 0.0017 - val_accuracy: 1.0000 - 7s/epoch - 250ms/step
# Epoch 5/80
# 29/29 - 8s - loss: 0.1754 - accuracy: 0.9371 - val_loss: 0.0533 - val_accuracy: 0.9802 - 8s/epoch - 261ms/step
# Epoch 6/80
# 29/29 - 7s - loss: 0.1319 - accuracy: 0.9470 - val_loss: 0.0810 - val_accuracy: 0.9802 - 7s/epoch - 251ms/step
# Epoch 7/80
# 29/29 - 7s - loss: 0.1208 - accuracy: 0.9592 - val_loss: 0.0943 - val_accuracy: 0.9505 - 7s/epoch - 257ms/step
# Epoch 8/80
# 29/29 - 7s - loss: 0.1451 - accuracy: 0.9625 - val_loss: 0.0901 - val_accuracy: 0.9703 - 7s/epoch - 255ms/step
# Epoch 9/80
# 29/29 - 7s - loss: 0.6888 - accuracy: 0.8642 - val_loss: 0.2635 - val_accuracy: 0.8878 - 7s/epoch - 253ms/step
# Epoch 10/80
# 29/29 - 7s - loss: 0.3790 - accuracy: 0.8863 - val_loss: 3.0871 - val_accuracy: 0.9208 - 7s/epoch - 252ms/step
# Epoch 11/80
# 29/29 - 8s - loss: 0.2250 - accuracy: 0.9150 - val_loss: 0.5284 - val_accuracy: 0.9736 - 8s/epoch - 265ms/step
# Epoch 12/80
# 29/29 - 7s - loss: 0.2585 - accuracy: 0.9238 - val_loss: 0.0799 - val_accuracy: 0.9736 - 7s/epoch - 251ms/step
# Epoch 13/80
# 29/29 - 8s - loss: 0.5344 - accuracy: 0.9051 - val_loss: 0.1243 - val_accuracy: 0.9406 - 8s/epoch - 262ms/step
# Epoch 14/80
# 29/29 - 7s - loss: 0.1639 - accuracy: 0.9459 - val_loss: 0.0266 - val_accuracy: 0.9868 - 7s/epoch - 253ms/step
# Epoch 15/80
# 29/29 - 7s - loss: 0.1962 - accuracy: 0.9161 - val_loss: 0.0306 - val_accuracy: 0.9934 - 7s/epoch - 255ms/step
# Epoch 16/80
# 29/29 - 8s - loss: 0.1560 - accuracy: 0.9536 - val_loss: 0.0288 - val_accuracy: 0.9868 - 8s/epoch - 259ms/step
# Epoch 17/80
# 29/29 - 7s - loss: 0.1239 - accuracy: 0.9636 - val_loss: 0.0088 - val_accuracy: 0.9967 - 7s/epoch - 257ms/step
# Epoch 18/80
# 29/29 - 7s - loss: 0.2747 - accuracy: 0.9084 - val_loss: 0.1225 - val_accuracy: 0.9670 - 7s/epoch - 256ms/step
# Epoch 19/80
# 29/29 - 7s - loss: 0.1869 - accuracy: 0.9249 - val_loss: 0.0384 - val_accuracy: 0.9802 - 7s/epoch - 255ms/step
# Epoch 20/80
# 29/29 - 7s - loss: 0.1370 - accuracy: 0.9470 - val_loss: 0.0108 - val_accuracy: 0.9901 - 7s/epoch - 257ms/step
# Epoch 21/80
# 29/29 - 8s - loss: 0.1730 - accuracy: 0.9404 - val_loss: 0.1309 - val_accuracy: 0.8878 - 8s/epoch - 263ms/step
# Epoch 22/80
# 29/29 - 7s - loss: 0.1619 - accuracy: 0.9547 - val_loss: 0.0201 - val_accuracy: 1.0000 - 7s/epoch - 257ms/step
# Epoch 23/80
# 29/29 - 7s - loss: 0.1178 - accuracy: 0.9547 - val_loss: 0.0270 - val_accuracy: 1.0000 - 7s/epoch - 256ms/step
# Epoch 24/80
# 29/29 - 8s - loss: 0.1184 - accuracy: 0.9570 - val_loss: 0.0178 - val_accuracy: 0.9967 - 8s/epoch - 261ms/step
# Epoch 25/80
# 29/29 - 7s - loss: 0.1745 - accuracy: 0.9360 - val_loss: 0.0138 - val_accuracy: 1.0000 - 7s/epoch - 257ms/step
# Epoch 26/80
# 29/29 - 7s - loss: 0.1382 - accuracy: 0.9536 - val_loss: 0.0293 - val_accuracy: 0.9934 - 7s/epoch - 257ms/step
# Epoch 27/80
# 29/29 - 8s - loss: 0.0947 - accuracy: 0.9658 - val_loss: 0.0287 - val_accuracy: 0.9901 - 8s/epoch - 263ms/step
# Epoch 28/80
# 29/29 - 7s - loss: 0.2187 - accuracy: 0.9205 - val_loss: 0.2647 - val_accuracy: 0.8482 - 7s/epoch - 256ms/step
# Epoch 29/80
# 29/29 - 7s - loss: 0.1900 - accuracy: 0.9194 - val_loss: 0.0246 - val_accuracy: 0.9967 - 7s/epoch - 258ms/step
# Epoch 30/80
# 29/29 - 7s - loss: 0.1373 - accuracy: 0.9581 - val_loss: 0.0396 - val_accuracy: 1.0000 - 7s/epoch - 253ms/step
# Epoch 31/80
# 29/29 - 8s - loss: 0.1094 - accuracy: 0.9636 - val_loss: 0.0458 - val_accuracy: 0.9868 - 8s/epoch - 259ms/step
# Epoch 32/80
# 29/29 - 7s - loss: 0.1310 - accuracy: 0.9570 - val_loss: 0.0120 - val_accuracy: 0.9967 - 7s/epoch - 252ms/step
# Epoch 33/80
# 29/29 - 7s - loss: 0.1017 - accuracy: 0.9558 - val_loss: 0.0099 - val_accuracy: 0.9934 - 7s/epoch - 254ms/step
# Epoch 34/80
# 29/29 - 7s - loss: 0.0958 - accuracy: 0.9658 - val_loss: 0.0195 - val_accuracy: 0.9901 - 7s/epoch - 255ms/step
# Epoch 35/80
# 29/29 - 8s - loss: 0.1056 - accuracy: 0.9658 - val_loss: 0.0260 - val_accuracy: 0.9868 - 8s/epoch - 261ms/step
# Epoch 36/80
# 29/29 - 8s - loss: 0.1321 - accuracy: 0.9647 - val_loss: 0.0272 - val_accuracy: 0.9934 - 8s/epoch - 263ms/step
# Epoch 37/80
# 29/29 - 7s - loss: 0.1324 - accuracy: 0.9558 - val_loss: 0.0531 - val_accuracy: 0.9868 - 7s/epoch - 258ms/step
# Epoch 38/80
# 29/29 - 8s - loss: 0.1029 - accuracy: 0.9647 - val_loss: 0.0097 - val_accuracy: 0.9934 - 8s/epoch - 262ms/step
# Epoch 39/80
# 29/29 - 7s - loss: 0.1011 - accuracy: 0.9746 - val_loss: 0.0095 - val_accuracy: 1.0000 - 7s/epoch - 257ms/step
# Epoch 40/80
# 29/29 - 8s - loss: 0.1133 - accuracy: 0.9625 - val_loss: 0.0191 - val_accuracy: 1.0000 - 8s/epoch - 260ms/step
# Epoch 41/80
# 29/29 - 7s - loss: 0.1195 - accuracy: 0.9570 - val_loss: 0.0188 - val_accuracy: 0.9967 - 7s/epoch - 255ms/step
# Epoch 42/80
# 29/29 - 8s - loss: 0.1383 - accuracy: 0.9658 - val_loss: 0.0094 - val_accuracy: 1.0000 - 8s/epoch - 261ms/step
# Epoch 43/80
# 29/29 - 8s - loss: 0.0913 - accuracy: 0.9691 - val_loss: 0.0565 - val_accuracy: 0.9736 - 8s/epoch - 262ms/step
# Epoch 44/80
# 29/29 - 7s - loss: 0.1145 - accuracy: 0.9492 - val_loss: 0.0036 - val_accuracy: 1.0000 - 7s/epoch - 256ms/step
# Epoch 45/80
# 29/29 - 8s - loss: 0.1270 - accuracy: 0.9603 - val_loss: 0.0141 - val_accuracy: 1.0000 - 8s/epoch - 266ms/step
# Epoch 46/80
# 29/29 - 8s - loss: 0.1061 - accuracy: 0.9691 - val_loss: 0.1586 - val_accuracy: 0.8977 - 8s/epoch - 263ms/step
# Epoch 47/80
# 29/29 - 7s - loss: 0.1606 - accuracy: 0.9525 - val_loss: 0.0102 - val_accuracy: 0.9967 - 7s/epoch - 256ms/step
# Epoch 48/80
# 29/29 - 8s - loss: 0.1794 - accuracy: 0.9448 - val_loss: 0.0139 - val_accuracy: 0.9967 - 8s/epoch - 262ms/step
# Epoch 49/80
# 29/29 - 7s - loss: 0.1028 - accuracy: 0.9636 - val_loss: 0.0145 - val_accuracy: 0.9934 - 7s/epoch - 254ms/step
# Epoch 50/80
# 29/29 - 8s - loss: 0.1380 - accuracy: 0.9503 - val_loss: 0.0091 - val_accuracy: 0.9967 - 8s/epoch - 263ms/step
# Epoch 51/80
# 29/29 - 7s - loss: 0.1068 - accuracy: 0.9581 - val_loss: 0.0200 - val_accuracy: 0.9967 - 7s/epoch - 255ms/step
# Epoch 52/80
# 29/29 - 7s - loss: 0.2317 - accuracy: 0.9536 - val_loss: 0.0304 - val_accuracy: 0.9901 - 7s/epoch - 254ms/step
# Epoch 53/80
# 29/29 - 7s - loss: 0.0856 - accuracy: 0.9680 - val_loss: 0.0852 - val_accuracy: 0.9868 - 7s/epoch - 254ms/step
# Epoch 54/80
# 29/29 - 7s - loss: 0.1326 - accuracy: 0.9625 - val_loss: 0.0811 - val_accuracy: 0.9868 - 7s/epoch - 254ms/step
# Epoch 55/80
# 29/29 - 8s - loss: 0.1010 - accuracy: 0.9713 - val_loss: 0.0219 - val_accuracy: 0.9901 - 8s/epoch - 263ms/step
# Epoch 56/80
# 29/29 - 7s - loss: 0.0728 - accuracy: 0.9746 - val_loss: 0.0338 - val_accuracy: 0.9901 - 7s/epoch - 255ms/step
# Epoch 57/80
# 29/29 - 7s - loss: 0.1054 - accuracy: 0.9680 - val_loss: 0.0102 - val_accuracy: 1.0000 - 7s/epoch - 258ms/step
# Epoch 58/80
# 29/29 - 7s - loss: 0.1037 - accuracy: 0.9636 - val_loss: 0.2440 - val_accuracy: 0.9208 - 7s/epoch - 256ms/step
# Epoch 59/80
# 29/29 - 7s - loss: 0.1226 - accuracy: 0.9592 - val_loss: 0.0142 - val_accuracy: 0.9934 - 7s/epoch - 255ms/step
# Epoch 60/80
# 29/29 - 8s - loss: 0.1018 - accuracy: 0.9614 - val_loss: 0.0182 - val_accuracy: 1.0000 - 8s/epoch - 259ms/step
# Epoch 61/80
# 29/29 - 8s - loss: 0.0841 - accuracy: 0.9702 - val_loss: 0.0209 - val_accuracy: 0.9967 - 8s/epoch - 264ms/step
# Epoch 62/80
# 29/29 - 7s - loss: 0.0746 - accuracy: 0.9790 - val_loss: 0.0147 - val_accuracy: 1.0000 - 7s/epoch - 252ms/step
# Epoch 63/80
# 29/29 - 8s - loss: 0.1855 - accuracy: 0.9547 - val_loss: 0.1682 - val_accuracy: 0.8746 - 8s/epoch - 262ms/step
# Epoch 64/80
# 29/29 - 7s - loss: 0.1937 - accuracy: 0.9327 - val_loss: 0.1288 - val_accuracy: 0.9010 - 7s/epoch - 257ms/step
# Epoch 65/80
# 29/29 - 7s - loss: 0.2675 - accuracy: 0.9338 - val_loss: 0.5369 - val_accuracy: 0.7987 - 7s/epoch - 257ms/step
# Epoch 66/80
# 29/29 - 8s - loss: 0.1981 - accuracy: 0.9238 - val_loss: 0.0500 - val_accuracy: 0.9868 - 8s/epoch - 261ms/step
# Epoch 67/80
# 29/29 - 8s - loss: 0.1762 - accuracy: 0.9503 - val_loss: 0.1906 - val_accuracy: 0.8845 - 8s/epoch - 259ms/step
# Epoch 68/80
# 29/29 - 7s - loss: 0.2010 - accuracy: 0.9216 - val_loss: 0.2074 - val_accuracy: 0.9340 - 7s/epoch - 251ms/step
# Epoch 69/80
# 29/29 - 8s - loss: 0.2168 - accuracy: 0.9272 - val_loss: 0.2034 - val_accuracy: 0.9109 - 8s/epoch - 262ms/step
# Epoch 70/80
# 29/29 - 7s - loss: 0.1441 - accuracy: 0.9492 - val_loss: 0.1048 - val_accuracy: 0.9340 - 7s/epoch - 257ms/step
# Epoch 71/80
# 29/29 - 7s - loss: 0.1136 - accuracy: 0.9547 - val_loss: 0.0322 - val_accuracy: 1.0000 - 7s/epoch - 255ms/step
# Epoch 72/80
# 29/29 - 7s - loss: 0.4385 - accuracy: 0.9525 - val_loss: 0.0289 - val_accuracy: 0.9868 - 7s/epoch - 256ms/step
# Epoch 73/80
# 29/29 - 7s - loss: 0.4052 - accuracy: 0.9349 - val_loss: 0.1052 - val_accuracy: 0.9505 - 7s/epoch - 257ms/step
# Epoch 74/80
# 29/29 - 7s - loss: 0.2817 - accuracy: 0.9404 - val_loss: 0.2100 - val_accuracy: 0.9208 - 7s/epoch - 257ms/step
# Epoch 75/80
# 29/29 - 7s - loss: 0.4023 - accuracy: 0.9194 - val_loss: 0.0214 - val_accuracy: 0.9967 - 7s/epoch - 256ms/step
# Epoch 76/80
# 29/29 - 7s - loss: 0.1433 - accuracy: 0.9503 - val_loss: 0.0355 - val_accuracy: 0.9967 - 7s/epoch - 258ms/step
# Epoch 77/80
# 29/29 - 7s - loss: 0.1420 - accuracy: 0.9426 - val_loss: 0.0503 - val_accuracy: 0.9934 - 7s/epoch - 253ms/step
# Epoch 78/80
# 29/29 - 7s - loss: 0.1131 - accuracy: 0.9570 - val_loss: 0.0313 - val_accuracy: 0.9967 - 7s/epoch - 255ms/step
# Epoch 79/80
# 29/29 - 8s - loss: 0.1558 - accuracy: 0.9481 - val_loss: 0.0431 - val_accuracy: 0.9967 - 8s/epoch - 261ms/step
# Epoch 80/80
# 29/29 - 7s - loss: 0.1170 - accuracy: 0.9570 - val_loss: 0.0476 - val_accuracy: 0.9967 - 7s/epoch - 256ms/step

# %%
def plot_graphs(trained_model_alexnet, string):
    plt.plot(trained_model_alexnet.history[string], label="train "+string)
    plt.plot(trained_model_alexnet.history['val_'+string], label="validation "+string)
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    
    
  #Plot the accuracy and loss
plot_graphs(trained_model_alexnet, "accuracy")
plot_graphs(trained_model_alexnet, "loss")

# %%
model_alexnet.save("Saved_models/model_alexnet.h5")

# %%
scores = model_alexnet.evaluate(X_test_images, y_test_labels, verbose=0)
print("AlexNet Accuracy on Test Set: %.2f%%" % (scores[1]*100))
# Out:
# AlexNet Accuracy on Test Set: 95.31%

# %%
_, train_acc = model_alexnet.evaluate(X_train_images, y_train_labels, verbose=0)
_, val_acc = model_alexnet.evaluate(X_val_images, y_val_labels, verbose=0)
_, test_acc = model_alexnet.evaluate(X_test_images, y_test_labels, verbose=0)
print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f' % (train_acc, val_acc, test_acc))
# Out:
# Train accuracy: 0.975, Validation accuracy: 0.997, Test accuracy: 0.953

# %% [markdown]
# ### Get accuracy, precision, recall and f measure and  confusion matrix

# %%
y_pred_labels = model_alexnet.predict(X_test_images)
y_pred_labels = y_pred_labels.flatten().round()
print(classification_report(y_test_labels, y_pred_labels, digits  =3))
# Out:
# 10/10 [==============================] - 0s 35ms/step
#               precision    recall  f1-score   support
#
#            0      0.925     0.980     0.952       151
#            1      0.981     0.927     0.953       164
#
#     accuracy                          0.952       315
#    macro avg      0.953     0.953     0.952       315
# weighted avg      0.954     0.952     0.952       315

# %%
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print('AlexNet model Accuracy:  %.3f' % accuracy)

precision = precision_score(y_test_labels, y_pred_labels)
print('AlexNet model Precision: %.3f' % precision)

recall = recall_score(y_test_labels, y_pred_labels)
print('AlexNet model Recall: %.3f' % recall)

f1 = f1_score(y_test_labels, y_pred_labels)
print('AlexNet model F1-score: %.3f' % f1)
# Out:
# AlexNet model Accuracy:  0.952
# AlexNet model Precision: 0.981
# AlexNet model Recall: 0.927
# AlexNet model F1-score: 0.953

# %%
cmatrix = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cmatrix)
disp.plot()
plt.show()
